# %% [markdown]
# # Day 3 — SQL Practice Questions: Date & Time Functions
#
# | # | Difficulty | Topic |
# |---|-----------|-------|
# | 1 | 🟢 Easy    | Find slow deliveries (date arithmetic) |
# | 2 | 🟢 Easy    | Monthly revenue totals (DATE_TRUNC + GROUP BY) |
# | 3 | 🟡 Medium  | New customers — first order in last 90 days (MIN + HAVING) |

# %%
# %load_ext sql
USERNAME = 'postgres'
PASSWORD = 'hariom'
HOST     = 'localhost'
PORT     = '5432'
DBNAME   = 'postgres'
# %sql postgresql://{USERNAME}:{PASSWORD}@{HOST}:{PORT}/{DBNAME}

# %% [markdown]
# ---
# # Question 1 🟢 — Slow Deliveries
#
# ## Concept Warm-up

# %%
# %%sql
# -- Day 3 SQL — Date & Time Functions
# -- Run this script once to create all required tables.
#
# -- ============================================================
# -- 1. Notebook exploration table: orders
# -- ============================================================
# DROP TABLE IF EXISTS orders;
#
# CREATE TABLE orders (
#     order_id    SERIAL PRIMARY KEY,
#     customer_id INTEGER        NOT NULL,
#     order_date  DATE           NOT NULL,
#     ship_date   DATE,
#     amount      NUMERIC(10, 2) NOT NULL
# );
#
# INSERT INTO orders (customer_id, order_date, ship_date, amount) VALUES
# -- Recent orders (within last 90 days from 2026-06-17)
# (1001, '2026-05-01', '2026-05-05', 250.00),
# (1002, '2026-05-03', '2026-05-14', 189.50),   -- slow: 11 days
# (1001, '2026-05-10', '2026-05-17', 310.00),   -- slow: 7 days (edge)
# (1003, '2026-05-15', '2026-05-23', 95.00),    -- slow: 8 days
# (1004, '2026-05-20', '2026-05-21', 540.00),
# (1002, '2026-06-01', '2026-06-03', 220.00),
# (1005, '2026-06-05', '2026-06-19', 75.00),    -- slow: 14 days
# (1003, '2026-06-10', '2026-06-12', 430.00),
# (1006, '2026-06-12', '2026-06-14', 180.00),   -- new customer, recent first order
# (1007, '2026-06-15', '2026-06-16', 99.00),    -- new customer, recent first order
# -- Older orders (2025 — outside last 90 days)
# (1001, '2025-01-05', '2025-01-07', 500.00),
# (1002, '2025-03-12', '2025-03-14', 320.00),
# (1003, '2025-06-20', '2025-07-01', 150.00),   -- slow: 11 days
# (1004, '2025-09-08', '2025-09-10', 780.00),
# (1005, '2025-11-25', '2025-11-30', 210.00),
# (1001, '2025-12-01', '2025-12-15', 640.00),   -- slow: 14 days
# (1002, '2025-12-20', '2025-12-22', 110.00),
# (1004, '2026-01-10', '2026-01-12', 920.00),
# (1001, '2026-02-14', '2026-02-16', 275.00),
# (1003, '2026-03-01', '2026-03-04', 360.00),
# (1002, '2026-03-18', '2026-03-20', 490.00),
# (1005, '2026-04-05', '2026-04-07', 130.00);
#
#
# -- ============================================================
# -- 2. Practice Question tables (pq_ prefix)
# -- ============================================================
#
# -- pq_orders: same structure, same data — used for practice questions
# DROP TABLE IF EXISTS pq_orders;
#
# CREATE TABLE pq_orders (
#     order_id    SERIAL PRIMARY KEY,
#     customer_id INTEGER        NOT NULL,
#     order_date  DATE           NOT NULL,
#     ship_date   DATE,
#     amount      NUMERIC(10, 2) NOT NULL
# );
#
# INSERT INTO pq_orders (customer_id, order_date, ship_date, amount)
# SELECT customer_id, order_date, ship_date, amount FROM orders;
#
#
# -- ============================================================
# -- Verify
# -- ============================================================
# SELECT 'orders'    AS tbl, COUNT(*) AS rows FROM orders
# UNION ALL
# SELECT 'pq_orders' AS tbl, COUNT(*) AS rows FROM pq_orders;
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# Done.
# Done.
# 22 rows affected.
# Done.
# Done.
# 22 rows affected.
# 2 rows affected.
# [('orders', 22), ('pq_orders', 22)]

# %%
# %%sql
# -- Warm-up 1: subtract two dates → integer days in PostgreSQL
# SELECT '2026-05-14'::date - '2026-05-03'::date AS days_diff;
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 1 rows affected.
# [(11,)]

# %%
# %%sql
# -- Warm-up 2: add interval to a date
# SELECT '2026-05-01'::date + INTERVAL '7 days'  AS plus_7,
#        '2026-05-01'::date + INTERVAL '30 days' AS plus_30,
#        '2026-05-01'::date + 14                  AS plus_14_shorthand;
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 1 rows affected.
# [(datetime.datetime(2026, 5, 8, 0, 0), datetime.datetime(2026, 5, 31, 0, 0), datetime.date(2026, 5, 15))]

# %%
# %%sql
# -- Warm-up 3: preview the pq_orders table
# SELECT order_id, customer_id, order_date, ship_date, amount
# FROM   pq_orders
# ORDER  BY order_date
# LIMIT  8;
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 8 rows affected.
# [(11, 1001, datetime.date(2025, 1, 5), datetime.date(2025, 1, 7), Decimal('500.00')),
#  (12, 1002, datetime.date(2025, 3, 12), datetime.date(2025, 3, 14), Decimal('320.00')),
#  (13, 1003, datetime.date(2025, 6, 20), datetime.date(2025, 7, 1), Decimal('150.00')),
#  (14, 1004, datetime.date(2025, 9, 8), datetime.date(2025, 9, 10), Decimal('780.00')),
#  (15, 1005, datetime.date(2025, 11, 25), datetime.date(2025, 11, 30), Decimal('210.00')),
#  (16, 1001, datetime.date(2025, 12, 1), datetime.date(2025, 12, 15), Decimal('640.00')),
#  (17, 1002, datetime.date(2025, 12, 20), datetime.date(2025, 12, 22), Decimal('110.00')),
#  (18, 1004, datetime.date(2026, 1, 10), datetime.date(2026, 1, 12), Decimal('920.00'))]

# %%
# %%sql
# -- Warm-up 4: compute delivery_days for all rows
# SELECT order_id,
#        order_date,
#        ship_date,
#        ship_date - order_date AS delivery_days
# FROM   pq_orders
# ORDER  BY delivery_days DESC
# LIMIT  5;
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 5 rows affected.
# [(7, datetime.date(2026, 6, 5), datetime.date(2026, 6, 19), 14),
#  (16, datetime.date(2025, 12, 1), datetime.date(2025, 12, 15), 14),
#  (13, datetime.date(2025, 6, 20), datetime.date(2025, 7, 1), 11),
#  (2, datetime.date(2026, 5, 3), datetime.date(2026, 5, 14), 11),
#  (4, datetime.date(2026, 5, 15), datetime.date(2026, 5, 23), 8)]

# %% [markdown]
# ## Problem
#
# The logistics team wants to review orders where the delivery took **more than 7 days**.
# Return `order_id`, `customer_id`, `order_date`, `ship_date`, and `delivery_days`, sorted by slowest delivery first.
#
# ```
# Expected: rows where ship_date - order_date > 7
# ```

# %%
# %%sql
# -- Warm-up 3: preview the pq_orders table
# SELECT order_id, customer_id, order_date, ship_date, amount
# FROM   pq_orders
# ORDER  BY order_date
# limit 10
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 10 rows affected.
# [(11, 1001, datetime.date(2025, 1, 5), datetime.date(2025, 1, 7), Decimal('500.00')),
#  (12, 1002, datetime.date(2025, 3, 12), datetime.date(2025, 3, 14), Decimal('320.00')),
#  (13, 1003, datetime.date(2025, 6, 20), datetime.date(2025, 7, 1), Decimal('150.00')),
#  (14, 1004, datetime.date(2025, 9, 8), datetime.date(2025, 9, 10), Decimal('780.00')),
#  (15, 1005, datetime.date(2025, 11, 25), datetime.date(2025, 11, 30), Decimal('210.00')),
#  (16, 1001, datetime.date(2025, 12, 1), datetime.date(2025, 12, 15), Decimal('640.00')),
#  (17, 1002, datetime.date(2025, 12, 20), datetime.date(2025, 12, 22), Decimal('110.00')),
#  (18, 1004, datetime.date(2026, 1, 10), datetime.date(2026, 1, 12), Decimal('920.00')),
#  (19, 1001, datetime.date(2026, 2, 14), datetime.date(2026, 2, 16), Decimal('275.00')),
#  (20, 1003, datetime.date(2026, 3, 1), datetime.date(2026, 3, 4), Decimal('360.00'))]

# %%
# %%sql
# -- YOUR QUERY HERE
# Out:
# UsageError: Cell magic `%%sql` not found.

# %% [markdown]
# ---
# # Question 2 🟢 — Monthly Revenue Totals
#
# ## Concept Warm-up

# %%
# %%sql
# -- Warm-up 1: DATE_TRUNC maps every date to the first of its month
# SELECT order_date,
#        DATE_TRUNC('month', order_date) AS month_start
# FROM   pq_orders
# LIMIT  6;
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 6 rows affected.
# [(datetime.date(2026, 5, 1), datetime.datetime(2026, 5, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))),
#  (datetime.date(2026, 5, 3), datetime.datetime(2026, 5, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))),
#  (datetime.date(2026, 5, 10), datetime.datetime(2026, 5, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))),
#  (datetime.date(2026, 5, 15), datetime.datetime(2026, 5, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))),
#  (datetime.date(2026, 5, 20), datetime.datetime(2026, 5, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))),
#  (datetime.date(2026, 6, 1), datetime.datetime(2026, 6, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))))]

# %%
# %%sql
# -- Warm-up 2: TO_CHAR formats a date as a readable label
# SELECT order_date,
#        TO_CHAR(order_date, 'YYYY-MM')  AS ym,
#        TO_CHAR(order_date, 'Mon YYYY') AS label
# FROM   pq_orders
# LIMIT  5;
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 5 rows affected.
# [(datetime.date(2026, 5, 1), '2026-05', 'May 2026'),
#  (datetime.date(2026, 5, 3), '2026-05', 'May 2026'),
#  (datetime.date(2026, 5, 10), '2026-05', 'May 2026'),
#  (datetime.date(2026, 5, 15), '2026-05', 'May 2026'),
#  (datetime.date(2026, 5, 20), '2026-05', 'May 2026')]

# %%
# %%sql
# -- Warm-up 3: GROUP BY DATE_TRUNC → chronological aggregation
# SELECT DATE_TRUNC('month', order_date) AS month,
#        COUNT(*) AS num_orders
# FROM   pq_orders
# GROUP  BY 1
# ORDER  BY 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 12 rows affected.
# [(datetime.datetime(2025, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))), 1),
#  (datetime.datetime(2025, 3, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))), 1),
#  (datetime.datetime(2025, 6, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))), 1),
#  (datetime.datetime(2025, 9, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))), 1),
#  (datetime.datetime(2025, 11, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))), 1),
#  (datetime.datetime(2025, 12, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))), 2),
#  (datetime.datetime(2026, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))), 1),
#  (datetime.datetime(2026, 2, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))), 1),
#  (datetime.datetime(2026, 3, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))), 2),
#  (datetime.datetime(2026, 4, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))), 1),
#  (datetime.datetime(2026, 5, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))), 5),
#  (datetime.datetime(2026, 6, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))), 5)]

# %% [markdown]
# ## Problem
#
# The finance team needs a **monthly revenue report**: total revenue, number of orders, and average order value per month, ordered from oldest to most recent.
# Display the month as `'YYYY-MM'` string in the output.
#
# ```
# Columns: month (YYYY-MM), total_revenue, num_orders, avg_order_value
# ```

# %%
# %%sql
# -- YOUR QUERY HERE
# # solve this and take it as a home work

# %% [markdown]
# ---
# # Question 3 🟡 — New Customers (First Order in Last 90 Days)
#
# ## Concept Warm-up

# %%
# %%sql
# -- Warm-up 1: CURRENT_DATE and 90-day window
# SELECT CURRENT_DATE                            AS today,
#        CURRENT_DATE - INTERVAL '90 days'       AS ninety_days_ago,
#        CURRENT_DATE - 90                       AS same_shorthand;

# %%
# %%sql
# -- Warm-up 2: MIN(order_date) per customer — first order date
# SELECT customer_id,
#        MIN(order_date) AS first_order_date,
#        COUNT(*)        AS total_orders
# FROM   pq_orders
# GROUP  BY customer_id
# ORDER  BY first_order_date;

# %%
# %%sql
# -- Warm-up 3: HAVING filters on aggregates — WHERE cannot
# -- Show customers with more than 2 orders
# SELECT customer_id, COUNT(*) AS num_orders
# FROM   pq_orders
# GROUP  BY customer_id
# HAVING COUNT(*) > 2
# ORDER  BY num_orders DESC;

# %%
# %%sql
# -- Warm-up 4: CURRENT_DATE - MIN(order_date) → days since first order
# SELECT customer_id,
#        MIN(order_date)                          AS first_order_date,
#        CURRENT_DATE - MIN(order_date)           AS days_since_first
# FROM   pq_orders
# GROUP  BY customer_id
# ORDER  BY days_since_first ASC;

# %% [markdown]
# ## Problem
#
# The growth team defines a **new customer** as someone whose **first-ever order** was placed within the last 90 days.
# Return `customer_id`, `first_order_date`, and `days_since_first_order`, sorted by most-recent first.
#
# **Hint:** Use `GROUP BY` + `MIN(order_date)` + `HAVING`.

# %%
# %%sql
# -- YOUR QUERY HERE
